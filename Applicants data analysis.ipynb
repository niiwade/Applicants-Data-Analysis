# %%
import matplotlib.pyplot as plt
import numpy as np
from math import pi
import pandas as pd

import seaborn as sn

# %%
df = pd.read_csv('Project.csv')
df
# Out:
#                              FullName                              Email  \
# 0                        EUGENE NUNOO            eugenia.nunoo@gmail.com
# 1             ABDUL-MUMIN ABDUL-JAWAD             tiyumbajawad@gmail.com
# 2                       ABRAHAM SELBY            selby.abraham@yahoo.com
# 3                       AGBESI CEPHAS            cephasagbesik@gmail.com
# 4                 AGBOKPE DENNIS KOFI             x_foundation@yahoo.com
# 5                 AGYEMANG CONSTANCE         agyemanconstance1@gmail.com
# 6                          ALBERT SAM              ASAM11929@HOTMAIL.COM
# 7                ALEXANDER KWAME ODEI               nanadei1@outlook.com
# 8                   AMOS THOMAS KWESI           nanakwasiamos0@gmail.com
# 9                 AMPIAH EMMANUEL JOE                ampiahjoe@gmail.com
# 10             ANTOINETTE EMEFA KEDZI               emephar982@gmail.com
# 11              APENTENG EMMANUEL ABU      apentengemmanuelabu@gmail.com
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 25 columns):
# FullName                            60 non-null object
# Email                               60 non-null object
# Phone                               60 non-null object
# Location                            60 non-null object
# Region                              60 non-null object
# DateOfBirth                         60 non-null object
# female                              60 non-null object
# NO                                  60 non-null object
# ProgrammingKnowledge                60 non-null object
# Instituition                        60 non-null object
# Bachelors                           60 non-null object
# CourseStudied                       60 non-null object
# PreferredCityForTrainig             60 non-null object
# EntrepreneurialExperience           60 non-null object
# ProgrammingLanguages                28 non-null object
# ...

# %%
df.isnull()
# Out:
#     FullName  Email  Phone  Location  Region  DateOfBirth  female     NO  \
# 0      False  False  False     False   False        False   False  False
# 1      False  False  False     False   False        False   False  False
# 2      False  False  False     False   False        False   False  False
# 3      False  False  False     False   False        False   False  False
# 4      False  False  False     False   False        False   False  False
# 5      False  False  False     False   False        False   False  False
# 6      False  False  False     False   False        False   False  False
# 7      False  False  False     False   False        False   False  False
# 8      False  False  False     False   False        False   False  False
# 9      False  False  False     False   False        False   False  False
# 10     False  False  False     False   False        False   False  False
# 11     False  False  False     False   False        False   False  False
# ...

# %%
#to call the 43 column
df.iloc[43]
# Out:
# FullName                                                                 Alex Quainoo
# Email                                                                apakq5@gmail.com
# Phone                                                                      0501430594
# Location                                                                Kaneshi-Accra
# Region                                                                  Greater Accra
# DateOfBirth                                                  1985-08-26T00:00:00.000Z
# female                                                                         female
# NO                                                                                 NO
# ProgrammingKnowledge                                                               NO
# Instituition                                                               University
# Bachelors                                                                   Bachelors
# ...

# %%
df['Location'].value_counts()
# Out:
# Accra                                         5
# Ashaiman                                      3
# Tema                                          2
# Adenta                                        2
# Madina                                        2
# TESHIE STAR PARK                              1
# SANTA MARIA                                   1
# North legon                                   1
# Rescue Estates, Accra                         1
# Nungua                                        1
# Kaneshi-Accra                                 1
# Labone, Accra                                 1
# Accra, Abelenkpe                              1
# ADJEI-KOJO, TEMA                              1
# TEMA                                          1
# Amasaman                                      1
# Lartebiokorshie                               1
# Amasaman                                      1
# 10 Ruby street, Achimota                      1
# Labone                                        1
# ...

# %%
df['ProgrammingKnowledge'].value_counts()
# Out:
# NO     35
# YES    25
# Name: ProgrammingKnowledge, dtype: int64

# %%
df['Instituition'].value_counts()
# Out:
# University              41
# Polytechnic             11
# Vocational/Technical     5
# Other                    3
# Name: Instituition, dtype: int64

# %%
df['Bachelors'].value_counts()
# Out:
# Bachelors    60
# Name: Bachelors, dtype: int64

# %%
df['HeardAboutUsThrough'].value_counts()
# Out:
# social media    33
# friends         25
# other            1
# website          1
# Name: HeardAboutUsThrough, dtype: int64

# %%
df['ProgrammingLanguages'].value_counts()
# Out:
# C++                                          3
# Python                                       2
# HTML, PHP, CSS                               1
# HTML,CSS,JS,VB,SQL,PHP                       1
# Programmiing with C++                        1
# English, Twi, Hausa, Ga, Dagbani             1
# MATLAB                                       1
# HTML                                         1
# HTML,CSS, Android                            1
# php                                          1
# ENGLISH, TWI                                 1
# Java, Flutter, React                         1
# Php, JS, C++, Html/CSS                       1
# HTML, CSS, Javascript                        1
# C#, JavaScript                               1
# Javascript, excel & access vba and python    1
# C#, Basic HTML                               1
# HTML, CSS                                    1
# Dart                                         1
# Python , C++, HTML, php                      1
# ...

# %%
#to plot par grahy 
#df['HeardAboutUsThrough'].value_counts().plot(kind='bar')
#plt.title('social media','friends','other','website')
#import seaborn as sn
#sn.countplot(df['HeardAboutUsThrough']).head(35))

students = [33,25,1,1]
HeardAboutUsThrough = ['social media','friends','other','website']
plt.bar(HeardAboutUsThrough,students)
plt.title('Number of people and how they heard program')
plt.xlabel('Heard about program through')
plt.ylabel('Number of people')
plt.grid(True)

# %%
#import seaborn as sn
#sn.countplot(df5_df['HeardAboutUsThrough']).head(60))

df['Instituition'].value_counts().head(60).plot.pie(autopct='%1.2f%%')
plt.show()

# %%
#to know the number of columns and rows
col=df.shape[1]
rows=df.shape[0]

print('columns = %d'%col)
print('rows = %d'%rows)
# Out:
# columns = 25
# rows = 60

# %%
df[['FullName','Region']]
# Out:
#                              FullName         Region
# 0                        EUGENE NUNOO  Greater Accra
# 1             ABDUL-MUMIN ABDUL-JAWAD  Greater Accra
# 2                       ABRAHAM SELBY  Greater Accra
# 3                       AGBESI CEPHAS  Greater Accra
# 4                 AGBOKPE DENNIS KOFI  Greater Accra
# 5                 AGYEMANG CONSTANCE   Greater Accra
# 6                          ALBERT SAM  Greater Accra
# 7                ALEXANDER KWAME ODEI  Greater Accra
# 8                   AMOS THOMAS KWESI  Greater Accra
# 9                 AMPIAH EMMANUEL JOE  Greater Accra
# 10             ANTOINETTE EMEFA KEDZI  Greater Accra
# 11              APENTENG EMMANUEL ABU  Greater Accra
# 12          ASIAMAH PAPA YAW KORANKYE  Greater Accra
# 13                 Abdul Aziz Suleman  Greater Accra
# 14              Abdul-Majeed Sulemana  Greater Accra
# 15         Abdul-mumuni Zubaeru Kaita  Greater Accra
# 16                   Abdulai Mohammed  Greater Accra
# ...

# %%
df[df['FullName'] == 'Ali Shaibu']
# Out:
#       FullName                       Email       Phone Location  \
# 46  Ali Shaibu  shaibu.ali.imran@gmail.com  0244553966   Madina
#
#            Region               DateOfBirth  female  NO ProgrammingKnowledge  \
# 46  Greater Accra  1985-09-19T00:00:00.000Z  female  NO                   NO
#
#    Instituition  ... ProgrammingLevel Employed CurrenRoleIfEmployed  \
# 46   University  ...                0       NO                  NaN
#
#                                            Motivation  \
# 46  To be exposed to new ideas and enhance my crea...
#
#    CurrentEnrolledInAnyProgram  FullParticipationForOneMonth  \
# 46                          NO                           YES
#
#    ReadyToCommitToIncubationProgram  ConsiderForInternship  \
# 46                              YES                    YES
#
#    HeardAboutUsThrough AIKnowledge
# 46             friends          NO
#
# [1 rows x 25 columns]

# %%
df[df['Location'] ==  'Amasaman']
# Out:
#                FullName                Email          Phone  Location  \
# 57  Andrew Amo-Korankye  akorankye@gmail.com  +233243649400  Amasaman
#
#            Region               DateOfBirth  female  NO ProgrammingKnowledge  \
# 57  Greater Accra  1986-05-21T00:00:00.000Z  female  NO                   NO
#
#    Instituition  ... ProgrammingLevel Employed CurrenRoleIfEmployed  \
# 57   University  ...                0       NO                  NaN
#
#                                            Motivation  \
# 57  Having been engaged agribusiness, I want to de...
#
#    CurrentEnrolledInAnyProgram  FullParticipationForOneMonth  \
# 57                          NO                           YES
#
#    ReadyToCommitToIncubationProgram  ConsiderForInternship  \
# 57                              YES                    YES
#
#    HeardAboutUsThrough AIKnowledge
# 57        social media          NO
#
# [1 rows x 25 columns]

# %%
#to create a smaller dataframe from the big one
df2 = df[['FullName','Email','Phone','Region']]
df2.head(10)
# Out:
#                   FullName                        Email             Phone  \
# 0             EUGENE NUNOO      eugenia.nunoo@gmail.com  +233 24 213 2615
# 1  ABDUL-MUMIN ABDUL-JAWAD       tiyumbajawad@gmail.com        0240771972
# 2            ABRAHAM SELBY      selby.abraham@yahoo.com        0542784867
# 3            AGBESI CEPHAS      cephasagbesik@gmail.com        0540509658
# 4      AGBOKPE DENNIS KOFI       x_foundation@yahoo.com        0547235323
# 5      AGYEMANG CONSTANCE   agyemanconstance1@gmail.com        0266595403
# 6               ALBERT SAM        ASAM11929@HOTMAIL.COM        0245707452
# 7     ALEXANDER KWAME ODEI         nanadei1@outlook.com        0207675264
# 8        AMOS THOMAS KWESI     nanakwasiamos0@gmail.com        0541478390
# 9      AMPIAH EMMANUEL JOE          ampiahjoe@gmail.com        0271287294
#
#           Region
# 0  Greater Accra
# 1  Greater Accra
# 2  Greater Accra
# 3  Greater Accra
# 4  Greater Accra
# 5  Greater Accra
# 6  Greater Accra
# ...

# %%
df2.shape
# Out:
# (60, 4)

# %%
df2.isnull()
# Out:
#     FullName  Email  Phone  Region
# 0      False  False  False   False
# 1      False  False  False   False
# 2      False  False  False   False
# 3      False  False  False   False
# 4      False  False  False   False
# 5      False  False  False   False
# 6      False  False  False   False
# 7      False  False  False   False
# 8      False  False  False   False
# 9      False  False  False   False
# 10     False  False  False   False
# 11     False  False  False   False
# 12     False  False  False   False
# 13     False  False  False   False
# 14     False  False  False   False
# 15     False  False  False   False
# 16     False  False  False   False
# 17     False  False  False   False
# 18     False  False  False   False
# 19     False  False  False   False
# 20     False  False  False   False
# 21     False  False  False   False
# 22     False  False  False   False
# 23     False  False  False   False
# 24     False  False  False   False
# 25     False  False  False   False
# ...
